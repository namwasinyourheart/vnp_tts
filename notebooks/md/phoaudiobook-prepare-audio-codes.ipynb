# %%
# !modal volume create prj-vol
# !modal volume create data-vol
# !modal volume create models-vol

# !modal secret create general WANDB_API_KEY=13ad03bbf5464ebb2b5f4532464556bcc17811a2 HUGGINGFACEHUB_API_TOKEN=REMOVEDRpSsYkbcJiDfMtdEIyrVZPSQlKWKJooDBL

# %%
import os
os.environ['HF_HOME'] = "/mnt/models-vol/cache_huggingface"
# !echo $HF_HOME
# Out:
# /mnt/models-vol/cache_huggingface

# %%
def setup_environment() -> None:
    import os
    from dotenv import load_dotenv
    _ = load_dotenv()

    from huggingface_hub import login
    login(token=os.environ['HUGGINGFACEHUB_API_TOKEN'])
   
setup_environment()

# %%
# !pip install datasets neucodec -q
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from datasets import load_dataset, load_from_disk

# %%
ds = load_dataset('thivux/phoaudiobook')
# Out:
# Resolving data files:   0%|          | 0/803 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/803 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/803 [00:00<?, ?files/s]
# data/train-00000-of-00803.parquet:   0%|          | 0.00/499M [00:00<?, ?B/s]
# data/train-00001-of-00803.parquet:   0%|          | 0.00/486M [00:00<?, ?B/s]
# data/train-00002-of-00803.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# data/train-00003-of-00803.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00004-of-00803.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# data/train-00005-of-00803.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# data/train-00006-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00007-of-00803.parquet:   0%|          | 0.00/491M [00:00<?, ?B/s]
# data/train-00008-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00009-of-00803.parquet:   0%|          | 0.00/478M [00:00<?, ?B/s]
# data/train-00010-of-00803.parquet:   0%|          | 0.00/468M [00:00<?, ?B/s]
# data/train-00011-of-00803.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# data/train-00012-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00013-of-00803.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# data/train-00014-of-00803.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# data/train-00015-of-00803.parquet:   0%|          | 0.00/460M [00:00<?, ?B/s]
# data/train-00016-of-00803.parquet:   0%|          | 0.00/434M [00:00<?, ?B/s]
# data/train-00017-of-00803.parquet:   0%|          | 0.00/461M [00:00<?, ?B/s]
# data/train-00018-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00019-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00020-of-00803.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# data/train-00021-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00022-of-00803.parquet:   0%|          | 0.00/484M [00:00<?, ?B/s]
# data/train-00023-of-00803.parquet:   0%|          | 0.00/483M [00:00<?, ?B/s]
# data/train-00024-of-00803.parquet:   0%|          | 0.00/482M [00:00<?, ?B/s]
# data/train-00025-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00026-of-00803.parquet:   0%|          | 0.00/482M [00:00<?, ?B/s]
# data/train-00027-of-00803.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# data/train-00028-of-00803.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# data/train-00029-of-00803.parquet:   0%|          | 0.00/483M [00:00<?, ?B/s]
# data/train-00030-of-00803.parquet:   0%|          | 0.00/430M [00:00<?, ?B/s]
# data/train-00031-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00032-of-00803.parquet:   0%|          | 0.00/484M [00:00<?, ?B/s]
# data/train-00033-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00034-of-00803.parquet:   0%|          | 0.00/451M [00:00<?, ?B/s]
# data/train-00035-of-00803.parquet:   0%|          | 0.00/458M [00:00<?, ?B/s]
# data/train-00036-of-00803.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# data/train-00037-of-00803.parquet:   0%|          | 0.00/454M [00:00<?, ?B/s]
# data/train-00038-of-00803.parquet:   0%|          | 0.00/492M [00:00<?, ?B/s]
# data/train-00039-of-00803.parquet:   0%|          | 0.00/480M [00:00<?, ?B/s]
# data/train-00040-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00041-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00042-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00043-of-00803.parquet:   0%|          | 0.00/466M [00:00<?, ?B/s]
# data/train-00044-of-00803.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# data/train-00045-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00046-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00047-of-00803.parquet:   0%|          | 0.00/486M [00:00<?, ?B/s]
# data/train-00048-of-00803.parquet:   0%|          | 0.00/468M [00:00<?, ?B/s]
# data/train-00049-of-00803.parquet:   0%|          | 0.00/487M [00:00<?, ?B/s]
# data/train-00050-of-00803.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00051-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00052-of-00803.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00053-of-00803.parquet:   0%|          | 0.00/459M [00:00<?, ?B/s]
# data/train-00054-of-00803.parquet:   0%|          | 0.00/468M [00:00<?, ?B/s]
# data/train-00055-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00056-of-00803.parquet:   0%|          | 0.00/473M [00:00<?, ?B/s]
# data/train-00057-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00058-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00059-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00060-of-00803.parquet:   0%|          | 0.00/456M [00:00<?, ?B/s]
# data/train-00061-of-00803.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# data/train-00062-of-00803.parquet:   0%|          | 0.00/482M [00:00<?, ?B/s]
# data/train-00063-of-00803.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# data/train-00064-of-00803.parquet:   0%|          | 0.00/431M [00:00<?, ?B/s]
# data/train-00065-of-00803.parquet:   0%|          | 0.00/480M [00:00<?, ?B/s]
# data/train-00066-of-00803.parquet:   0%|          | 0.00/461M [00:00<?, ?B/s]
# data/train-00067-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00068-of-00803.parquet:   0%|          | 0.00/473M [00:00<?, ?B/s]
# data/train-00069-of-00803.parquet:   0%|          | 0.00/498M [00:00<?, ?B/s]
# data/train-00070-of-00803.parquet:   0%|          | 0.00/487M [00:00<?, ?B/s]
# data/train-00071-of-00803.parquet:   0%|          | 0.00/480M [00:00<?, ?B/s]
# data/train-00072-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00073-of-00803.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# data/train-00074-of-00803.parquet:   0%|          | 0.00/395M [00:00<?, ?B/s]
# data/train-00075-of-00803.parquet:   0%|          | 0.00/473M [00:00<?, ?B/s]
# data/train-00076-of-00803.parquet:   0%|          | 0.00/462M [00:00<?, ?B/s]
# data/train-00077-of-00803.parquet:   0%|          | 0.00/461M [00:00<?, ?B/s]
# data/train-00078-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00079-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00080-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00081-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00082-of-00803.parquet:   0%|          | 0.00/478M [00:00<?, ?B/s]
# data/train-00083-of-00803.parquet:   0%|          | 0.00/462M [00:00<?, ?B/s]
# data/train-00084-of-00803.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# data/train-00085-of-00803.parquet:   0%|          | 0.00/475M [00:00<?, ?B/s]
# data/train-00086-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00087-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00088-of-00803.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# data/train-00089-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00090-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00091-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00092-of-00803.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# data/train-00093-of-00803.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00094-of-00803.parquet:   0%|          | 0.00/452M [00:00<?, ?B/s]
# data/train-00095-of-00803.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# data/train-00096-of-00803.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# data/train-00097-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00098-of-00803.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# data/train-00099-of-00803.parquet:   0%|          | 0.00/484M [00:00<?, ?B/s]
# data/train-00100-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00101-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00102-of-00803.parquet:   0%|          | 0.00/456M [00:00<?, ?B/s]
# data/train-00103-of-00803.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# data/train-00104-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00105-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00106-of-00803.parquet:   0%|          | 0.00/479M [00:00<?, ?B/s]
# data/train-00107-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00108-of-00803.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00109-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00110-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00111-of-00803.parquet:   0%|          | 0.00/483M [00:00<?, ?B/s]
# data/train-00112-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00113-of-00803.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# data/train-00114-of-00803.parquet:   0%|          | 0.00/483M [00:00<?, ?B/s]
# data/train-00115-of-00803.parquet:   0%|          | 0.00/453M [00:00<?, ?B/s]
# data/train-00116-of-00803.parquet:   0%|          | 0.00/462M [00:00<?, ?B/s]
# data/train-00117-of-00803.parquet:   0%|          | 0.00/483M [00:00<?, ?B/s]
# data/train-00118-of-00803.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# data/train-00119-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00120-of-00803.parquet:   0%|          | 0.00/456M [00:00<?, ?B/s]
# data/train-00121-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00122-of-00803.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# data/train-00123-of-00803.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# data/train-00124-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00125-of-00803.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# data/train-00126-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00127-of-00803.parquet:   0%|          | 0.00/480M [00:00<?, ?B/s]
# data/train-00128-of-00803.parquet:   0%|          | 0.00/459M [00:00<?, ?B/s]
# data/train-00129-of-00803.parquet:   0%|          | 0.00/456M [00:00<?, ?B/s]
# data/train-00130-of-00803.parquet:   0%|          | 0.00/468M [00:00<?, ?B/s]
# data/train-00131-of-00803.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# data/train-00132-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00133-of-00803.parquet:   0%|          | 0.00/461M [00:00<?, ?B/s]
# data/train-00134-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00135-of-00803.parquet:   0%|          | 0.00/450M [00:00<?, ?B/s]
# data/train-00136-of-00803.parquet:   0%|          | 0.00/447M [00:00<?, ?B/s]
# data/train-00137-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00138-of-00803.parquet:   0%|          | 0.00/459M [00:00<?, ?B/s]
# data/train-00139-of-00803.parquet:   0%|          | 0.00/488M [00:00<?, ?B/s]
# data/train-00140-of-00803.parquet:   0%|          | 0.00/484M [00:00<?, ?B/s]
# data/train-00141-of-00803.parquet:   0%|          | 0.00/480M [00:00<?, ?B/s]
# data/train-00142-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00143-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00144-of-00803.parquet:   0%|          | 0.00/472M [00:00<?, ?B/s]
# data/train-00145-of-00803.parquet:   0%|          | 0.00/479M [00:00<?, ?B/s]
# data/train-00146-of-00803.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# data/train-00147-of-00803.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# data/train-00148-of-00803.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# data/train-00149-of-00803.parquet:   0%|          | 0.00/456M [00:00<?, ?B/s]
# data/train-00150-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00151-of-00803.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# data/train-00152-of-00803.parquet:   0%|          | 0.00/488M [00:00<?, ?B/s]
# data/train-00153-of-00803.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# data/train-00154-of-00803.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# data/train-00155-of-00803.parquet:   0%|          | 0.00/484M [00:00<?, ?B/s]
# data/train-00156-of-00803.parquet:   0%|          | 0.00/473M [00:00<?, ?B/s]
# data/train-00157-of-00803.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# data/train-00158-of-00803.parquet:   0%|          | 0.00/482M [00:00<?, ?B/s]
# data/train-00159-of-00803.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# data/train-00160-of-00803.parquet:   0%|          | 0.00/462M [00:00<?, ?B/s]
# data/train-00161-of-00803.parquet:   0%|          | 0.00/456M [00:00<?, ?B/s]
# data/train-00162-of-00803.parquet:   0%|          | 0.00/449M [00:00<?, ?B/s]
# data/train-00163-of-00803.parquet:   0%|          | 0.00/459M [00:00<?, ?B/s]
# data/train-00164-of-00803.parquet:   0%|          | 0.00/454M [00:00<?, ?B/s]
# data/train-00165-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00166-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00167-of-00803.parquet:   0%|          | 0.00/448M [00:00<?, ?B/s]
# data/train-00168-of-00803.parquet:   0%|          | 0.00/453M [00:00<?, ?B/s]
# data/train-00169-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00170-of-00803.parquet:   0%|          | 0.00/437M [00:00<?, ?B/s]
# data/train-00171-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00172-of-00803.parquet:   0%|          | 0.00/484M [00:00<?, ?B/s]
# data/train-00173-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00174-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00175-of-00803.parquet:   0%|          | 0.00/459M [00:00<?, ?B/s]
# data/train-00176-of-00803.parquet:   0%|          | 0.00/457M [00:00<?, ?B/s]
# data/train-00177-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00178-of-00803.parquet:   0%|          | 0.00/453M [00:00<?, ?B/s]
# data/train-00179-of-00803.parquet:   0%|          | 0.00/437M [00:00<?, ?B/s]
# data/train-00180-of-00803.parquet:   0%|          | 0.00/468M [00:00<?, ?B/s]
# data/train-00181-of-00803.parquet:   0%|          | 0.00/452M [00:00<?, ?B/s]
# data/train-00182-of-00803.parquet:   0%|          | 0.00/433M [00:00<?, ?B/s]
# data/train-00183-of-00803.parquet:   0%|          | 0.00/446M [00:00<?, ?B/s]
# data/train-00184-of-00803.parquet:   0%|          | 0.00/458M [00:00<?, ?B/s]
# data/train-00185-of-00803.parquet:   0%|          | 0.00/485M [00:00<?, ?B/s]
# data/train-00186-of-00803.parquet:   0%|          | 0.00/479M [00:00<?, ?B/s]
# data/train-00187-of-00803.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# data/train-00188-of-00803.parquet:   0%|          | 0.00/475M [00:00<?, ?B/s]
# data/train-00189-of-00803.parquet:   0%|          | 0.00/450M [00:00<?, ?B/s]
# data/train-00190-of-00803.parquet:   0%|          | 0.00/476M [00:00<?, ?B/s]
# data/train-00191-of-00803.parquet:   0%|          | 0.00/491M [00:00<?, ?B/s]
# data/train-00192-of-00803.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# data/train-00193-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00194-of-00803.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# data/train-00195-of-00803.parquet:   0%|          | 0.00/486M [00:00<?, ?B/s]
# data/train-00196-of-00803.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# data/train-00197-of-00803.parquet:   0%|          | 0.00/475M [00:00<?, ?B/s]
# data/train-00198-of-00803.parquet:   0%|          | 0.00/474M [00:00<?, ?B/s]
# data/train-00199-of-00803.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# data/train-00200-of-00803.parquet:   0%|          | 0.00/457M [00:00<?, ?B/s]
# data/train-00201-of-00803.parquet:   0%|          | 0.00/466M [00:00<?, ?B/s]
# data/train-00202-of-00803.parquet:   0%|          | 0.00/468M [00:00<?, ?B/s]
# data/train-00203-of-00803.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# data/train-00204-of-00803.parquet:   0%|          | 0.00/466M [00:00<?, ?B/s]
# data/train-00205-of-00803.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# data/train-00206-of-00803.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# data/train-00207-of-00803.parquet:   0%|          | 0.00/452M [00:00<?, ?B/s]
# data/train-00208-of-00803.parquet:   0%|          | 0.00/484M [00:00<?, ?B/s]
# data/train-00209-of-00803.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00210-of-00803.parquet:   0%|          | 0.00/475M [00:00<?, ?B/s]
# data/train-00211-of-00803.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# data/train-00212-of-00803.parquet:   0%|          | 0.00/461M [00:00<?, ?B/s]
# data/train-00213-of-00803.parquet:   0%|          | 0.00/454M [00:00<?, ?B/s]
# data/train-00214-of-00803.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00215-of-00803.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00216-of-00803.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# data/train-00217-of-00803.parquet:   0%|          | 0.00/479M [00:00<?, ?B/s]
# data/train-00218-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00219-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00220-of-00803.parquet:   0%|          | 0.00/473M [00:00<?, ?B/s]
# data/train-00221-of-00803.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# data/train-00222-of-00803.parquet:   0%|          | 0.00/475M [00:00<?, ?B/s]
# data/train-00223-of-00803.parquet:   0%|          | 0.00/228M [00:00<?, ?B/s]
# data/train-00224-of-00803.parquet:   0%|          | 0.00/134M [00:00<?, ?B/s]
# data/train-00225-of-00803.parquet:   0%|          | 0.00/138M [00:00<?, ?B/s]
# data/train-00226-of-00803.parquet:   0%|          | 0.00/111M [00:00<?, ?B/s]
# data/train-00227-of-00803.parquet:   0%|          | 0.00/114M [00:00<?, ?B/s]
# data/train-00228-of-00803.parquet:   0%|          | 0.00/114M [00:00<?, ?B/s]
# data/train-00229-of-00803.parquet:   0%|          | 0.00/113M [00:00<?, ?B/s]
# data/train-00230-of-00803.parquet:   0%|          | 0.00/108M [00:00<?, ?B/s]
# data/train-00231-of-00803.parquet:   0%|          | 0.00/112M [00:00<?, ?B/s]
# data/train-00232-of-00803.parquet:   0%|          | 0.00/94.5M [00:00<?, ?B/s]
# data/train-00233-of-00803.parquet:   0%|          | 0.00/96.7M [00:00<?, ?B/s]
# data/train-00234-of-00803.parquet:   0%|          | 0.00/117M [00:00<?, ?B/s]
# data/train-00235-of-00803.parquet:   0%|          | 0.00/119M [00:00<?, ?B/s]
# data/train-00236-of-00803.parquet:   0%|          | 0.00/104M [00:00<?, ?B/s]
# data/train-00237-of-00803.parquet:   0%|          | 0.00/86.3M [00:00<?, ?B/s]
# data/train-00238-of-00803.parquet:   0%|          | 0.00/101M [00:00<?, ?B/s]
# data/train-00239-of-00803.parquet:   0%|          | 0.00/99.8M [00:00<?, ?B/s]
# data/train-00240-of-00803.parquet:   0%|          | 0.00/120M [00:00<?, ?B/s]
# data/train-00241-of-00803.parquet:   0%|          | 0.00/135M [00:00<?, ?B/s]
# data/train-00242-of-00803.parquet:   0%|          | 0.00/113M [00:00<?, ?B/s]
# data/train-00243-of-00803.parquet:   0%|          | 0.00/93.2M [00:00<?, ?B/s]
# data/train-00244-of-00803.parquet:   0%|          | 0.00/107M [00:00<?, ?B/s]
# data/train-00245-of-00803.parquet:   0%|          | 0.00/124M [00:00<?, ?B/s]
# data/train-00246-of-00803.parquet:   0%|          | 0.00/113M [00:00<?, ?B/s]
# data/train-00247-of-00803.parquet:   0%|          | 0.00/112M [00:00<?, ?B/s]
# data/train-00248-of-00803.parquet:   0%|          | 0.00/113M [00:00<?, ?B/s]
# data/train-00249-of-00803.parquet:   0%|          | 0.00/123M [00:00<?, ?B/s]
# data/train-00250-of-00803.parquet:   0%|          | 0.00/100M [00:00<?, ?B/s]
# data/train-00251-of-00803.parquet:   0%|          | 0.00/104M [00:00<?, ?B/s]
# data/train-00252-of-00803.parquet:   0%|          | 0.00/100M [00:00<?, ?B/s]
# data/train-00253-of-00803.parquet:   0%|          | 0.00/117M [00:00<?, ?B/s]
# data/train-00254-of-00803.parquet:   0%|          | 0.00/113M [00:00<?, ?B/s]
# data/train-00255-of-00803.parquet:   0%|          | 0.00/110M [00:00<?, ?B/s]

# %%
ds.save_to_disk("/mnt/data-vol/thivux__phoaudiobook"

# %%
# %%writefile /mnt/data-vol/prepare_audio_codec.py
from datasets import load_dataset, load_from_disk

def get_audio_codes(example, model):
    audio = example["audio"]["array"]

    # (T,) -> (1, 1, T)
    y = torch.from_numpy(audio).float().unsqueeze(0).unsqueeze(0).cuda()

    with torch.no_grad():
        codes = model.encode_code(y)

    return {
        "codes": codes.flatten().cpu().tolist()
    }

import torch

def get_audio_codes_batched(examples, model):
    """
    Encode từng audio riêng lẻ, rồi append codes vào list
    """

    all_codes = []

    for audio in examples["audio"]:
        # (T,) -> (1, 1, T)
        y = (
            torch.from_numpy(audio["array"])
            .float()
            .unsqueeze(0)
            .unsqueeze(0)
            # .cuda()
        )

        with torch.no_grad():
            codes = model.encode_code(y)

        # remove batch dim, flatten
        codes = codes.squeeze(0).flatten().cpu().tolist()
        all_codes.append(codes)

    return {
        "codes": all_codes
    }


def add_sample_id(dataset, start=0, prefix=None, width=0, column_name="sid"):
    """
    Add sample_id column to a HuggingFace Dataset.

    dataset     : datasets.Dataset
    start       : starting id
    prefix      : optional prefix (e.g. 's')
    width       : zero-padding width
    column_name : name of id column (default 'sid')
    """
    def format_sid(i):
        if width > 0:
            num = f"{i:0{width}d}"
        else:
            num = str(i)

        return f"{prefix}{num}" if prefix else num

    sids = [format_sid(i) for i in range(start, start + len(dataset))]
    return dataset.add_column(column_name, sids)


import os
import re


def cleanup_locks(locks_dir, codes_dir):
    """
    Remove lock directories that do NOT have corresponding output folder.
    Keep only locks for completed chunks.
    """

    lock_re = re.compile(r"chunk_(\d+)_(\d+)\.lock$")
    code_re = re.compile(r".*_(\d+)_(\d+)$")

    # ---- completed chunks from codes dir ----
    completed = set()
    for name in os.listdir(codes_dir):
        m = code_re.match(name)
        if m:
            start, end_inclusive = map(int, m.groups())
            completed.add((start, end_inclusive))

    removed = []
    kept = []

    # ---- clean locks ----
    for name in os.listdir(locks_dir):
        m = lock_re.match(name)
        if not m:
            continue

        start, end = map(int, m.groups())
        lock_path = os.path.join(locks_dir, name)

        if (start, end) in completed:
            kept.append(name)
        else:
            # not completed → remove lock dir
            os.rmdir(lock_path)
            removed.append(name)

    return kept, removed



if __name__ == "__main__":

    from neucodec import NeuCodec
    from math import ceil
    import os

    model = NeuCodec.from_pretrained("neuphonic/neucodec")
    model.eval().cuda()
    model.eval()

    # dataset_name = "vivos"
    # dataset = load_dataset(dataset_name)

    dataset_name = "/mnt/data-vol/thivux__phoaudiobook"
    ds = load_from_disk(dataset_name)

    
    print("Adding sample_id...")
    ds["train"] = add_sample_id(ds["train"])
    ds["validation"] = add_sample_id(ds["validation"])
    ds["test"] = add_sample_id(ds["test"])

    print("Compute audio codes...")
    dataset = ds['train']

    import argparse

    parser = argparse.ArgumentParser()
    parser.add_argument("--from_chunk", type=int, default=0,
                        help="start chunk index (inclusive)")
    parser.add_argument("--to_chunk", type=int, default=None,
                        help="end chunk index (exclusive)")
    args = parser.parse_args()
    

    
    
    chunk_size = 1_000
    num_samples = len(dataset)
    num_chunks = ceil(num_samples / chunk_size)

    
    LOCK_DIR = "/mnt/data-vol/phoaudiobook/interim/audio_codes/locks"
    OUT_DIR = "/mnt/data-vol/phoaudiobook/interim/audio_codes/codes"

    # os.makedirs('/mnt/data-vol/audio_codes', exist_ok=True)
    
    os.makedirs(LOCK_DIR, exist_ok=True)
    os.makedirs(OUT_DIR, exist_ok=True)

    locks_dir = LOCK_DIR
    codes_dir = OUT_DIR
    
    # cleanup_locks(locks_dir, codes_dir)
    
    # model = load_model().to("cuda")

    # chunk_range = range(800, num_chunks)

    start_chunk = args.from_chunk
    end_chunk = args.to_chunk if args.to_chunk is not None else num_chunks
    
    chunk_range = range(start_chunk, min(end_chunk, num_chunks))

    
    for chunk_idx in chunk_range:
        start = chunk_idx * chunk_size
        end = min(start + chunk_size, num_samples)
    
        lock_path = f"{LOCK_DIR}/chunk_{start}_{end-1}.lock"
        out_path = f"{OUT_DIR}/train_neucodec_{start}_{end-1}"
    
        # 이미 xử lý xong
        if os.path.exists(out_path):
            continue
    
        # try to claim chunk
        try:
            os.mkdir(lock_path)
        except FileExistsError:
            # chunk đang bị script khác xử lý
            continue
    
        print(f"Processing chunk {start}-{end-1}")
    
        try:
            ds_chunk = dataset.select(range(start, end))
    
            ds_chunk = ds_chunk.map(
                get_audio_codes,
                fn_kwargs={"model": model},
                # batched=True,
                # batch_size=64,
                desc=f"Chunk {start}-{end-1}",
            )
    
            ds_chunk.save_to_disk(out_path)
    
        except Exception as e:
            print(f"Error in chunk {start}-{end-1}: {e}")
            # nếu fail → xoá lock để script khác retry
            os.rmdir(lock_path)
            raise
    
        # done → giữ lock lại như dấu đã xong (hoặc xoá cũng được)
